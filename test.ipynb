# %%
'''
Emotion Detection Using AI
'''

#USAGE : python test.py

from keras.models import load_model
from time import sleep
from keras.preprocessing.image import img_to_array
from keras.preprocessing import image
import cv2
import numpy as np

face_classifier = cv2.CascadeClassifier('./haarcascade_frontalface_default.xml')
classifier =load_model('./Emotion_Detection.h5')

class_labels = ['Angry','Happy','Neutral','Sad','Surprise']

cap = cv2.VideoCapture(0)



while True:
    # Grab a single frame of video
    ret, frame = cap.read()
    labels = []
    gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray,1.3,5)

    for (x,y,w,h) in faces:
        cv2.rectangle(frame,(x,y),(x+w,y+h),(255,0,0),2)
        roi_gray = gray[y:y+h,x:x+w]
        roi_gray = cv2.resize(roi_gray,(48,48),interpolation=cv2.INTER_AREA)


        if np.sum([roi_gray])!=0:
            roi = roi_gray.astype('float')/255.0
            roi = img_to_array(roi)
            roi = np.expand_dims(roi,axis=0)

        # make a prediction on the ROI, then lookup the class

            preds = classifier.predict(roi)[0]
            print("\nprediction = ",preds)
            label=class_labels[preds.argmax()]
            print("\nprediction max = ",preds.argmax())
            print("\nlabel = ",label)
            label_position = (x,y)
            cv2.putText(frame,label,label_position,cv2.FONT_HERSHEY_SIMPLEX,2,(0,255,0),3)
        else:
            cv2.putText(frame,'No Face Found',(20,60),cv2.FONT_HERSHEY_SIMPLEX,2,(0,255,0),3)
        print("\n\n")
    cv2.imshow('Emotion Detector',frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# prediction =  [0.09918136 0.02855496 0.6112027  0.22597192 0.035089  ]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.00820702 0.86390144 0.1030522  0.01909627 0.00574309]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.00752678 0.8777077  0.09224991 0.01800318 0.00451241]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.01515943 0.68237215 0.25957513 0.03390197 0.0089914 ]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.00988776 0.77844805 0.18344128 0.02226123 0.00596179]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.00873517 0.7927936  0.17374629 0.01882731 0.00589766]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.01242482 0.7225765  0.22902974 0.02675221 0.00921672]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.04991525 0.01237212 0.848806   0.08228473 0.00662184]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.04781512 0.00637437 0.8598754  0.07912128 0.00681391]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.05186334 0.00579343 0.84918725 0.08646484 0.00669116]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.0527461  0.00499741 0.8448657  0.0904045  0.0069863 ]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.06317133 0.00490951 0.8151374  0.10911231 0.00766953]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.06516834 0.00386631 0.8089523  0.11402425 0.0079887 ]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.06427838 0.00378968 0.813387   0.1106723  0.00787264]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.06383999 0.00358742 0.81059414 0.11156482 0.01041355]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.07718334 0.00355071 0.7704049  0.13759318 0.011268  ]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.05819649 0.00474801 0.82340604 0.10389526 0.00975427]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.03949463 0.01658713 0.87168056 0.06447238 0.00776534]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.03328892 0.03498038 0.8636351  0.05566903 0.01242661]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.04576604 0.03191225 0.82148707 0.08322966 0.017605  ]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.04245981 0.01016849 0.8706244  0.07029316 0.00645415]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.03104166 0.00840443 0.9088806  0.04803718 0.00363615]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.03166775 0.00901984 0.9065145  0.04899562 0.00380223]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.02847124 0.0118912  0.9123783  0.04369689 0.00356239]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.02605268 0.01409935 0.91696686 0.0392676  0.00361357]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.02817198 0.01100129 0.91417533 0.04299809 0.00365327]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.03166912 0.01110717 0.90426934 0.04882048 0.00413383]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.03575994 0.00995214 0.8939482  0.05609689 0.0042429 ]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.0954841  0.04008573 0.61853415 0.22389768 0.02199831]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.06566919 0.01427965 0.7935799  0.11812053 0.00835085]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.1535679  0.17165701 0.2178761  0.42000964 0.03688933]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.15128455 0.1253779  0.23810768 0.45223045 0.03299945]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.17305622 0.17245181 0.24065354 0.36870912 0.0451293 ]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.12320234 0.03458035 0.40798664 0.4094872  0.02474348]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.12446223 0.08118387 0.5149914  0.2078427  0.07151987]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.05987705 0.02612058 0.7954389  0.10248709 0.01607637]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.05522011 0.01240121 0.82979876 0.09327209 0.00930781]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.049421   0.01125919 0.8501427  0.08131786 0.00785925]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.07193872 0.03496412 0.75155646 0.1271289  0.01441181]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.08268155 0.04928996 0.680098   0.16294925 0.02498129]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.09713705 0.11081688 0.52589947 0.244844   0.0213025 ]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.07729039 0.0301987  0.72593856 0.1522563  0.01431598]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.08464876 0.06362655 0.6367081  0.17388017 0.04113645]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.11902771 0.44112256 0.16726027 0.25580314 0.01678635]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.15365404 0.163      0.2164574  0.43427533 0.0326132 ]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.08886497 0.464327   0.19374596 0.24084891 0.01221313]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.04333399 0.52559775 0.320469   0.09688302 0.0137163 ]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.14841616 0.11854462 0.20899859 0.49915314 0.02488752]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.03744598 0.0464679  0.8421889  0.0597454  0.01415184]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.00449992 0.96151656 0.02378275 0.00851466 0.00168606]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.00458436 0.9545559  0.03029289 0.00848577 0.00208102]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.00358512 0.9648318  0.02310338 0.00667025 0.0018095 ]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.00392862 0.9574556  0.0287719  0.00751139 0.00233254]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.00290871 0.974412   0.01642594 0.00493843 0.00131493]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.11177487 0.12185722 0.54055434 0.21387857 0.01193497]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.14147405 0.02778476 0.55030495 0.27136335 0.00907295]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.13520014 0.02363338 0.57325965 0.2529288  0.01497806]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.11577629 0.02829772 0.62894356 0.20964505 0.01733738]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.11575562 0.02344881 0.6384016  0.20532414 0.01706987]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.13171378 0.01432486 0.61153954 0.22706021 0.01536163]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.0646383  0.02992701 0.75566936 0.11845098 0.03131434]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.05560771 0.0208104  0.43515322 0.1032026  0.38522604]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.05849981 0.01418174 0.58148235 0.11175042 0.23408568]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.05712697 0.01617446 0.774207   0.10569446 0.04679706]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.05705725 0.01605623 0.71348155 0.1051475  0.10825753]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.06017365 0.01067907 0.7582644  0.11071298 0.06016991]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.0535263  0.01247145 0.7882893  0.09765685 0.04805614]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.05962003 0.01540939 0.7562567  0.11179744 0.05691641]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.05895723 0.02156403 0.71536493 0.11056796 0.09354583]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.05556171 0.02771416 0.5497657  0.10728062 0.25967774]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0.04746316 0.5309352  0.21364376 0.08999378 0.11796411]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.04208028 0.51305836 0.17706089 0.06299613 0.20480429]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.03813367 0.6338307  0.0630158  0.03550589 0.2295138 ]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.1517417  0.16558607 0.24148804 0.4054292  0.03575498]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.15664358 0.16426253 0.24076894 0.3983923  0.03993262]
#
# prediction max =  3
#
# label =  Sad
# prediction =  [0.03044193 0.0358954  0.05905989 0.03171225 0.84289056]
#
# prediction max =  4
#
# label =  Surprise
#
#
#
#
# prediction =  [0.0196678  0.02172423 0.04168241 0.01947627 0.89744925]
#
# prediction max =  4
#
# label =  Surprise
#
#
#
#
# prediction =  [0.00868878 0.01261271 0.00989681 0.00513449 0.9636673 ]
#
# prediction max =  4
#
# label =  Surprise
#
#
#
#
# prediction =  [0.0077002  0.01071275 0.007012   0.00377002 0.97080505]
#
# prediction max =  4
#
# label =  Surprise
#
#
#
#
# prediction =  [0.00750404 0.0087789  0.00759687 0.00385882 0.97226137]
#
# prediction max =  4
#
# label =  Surprise
#
#
#
#
# prediction =  [0.03361457 0.4941873  0.2928485  0.06734606 0.11200365]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.00226495 0.95079815 0.04004475 0.00444994 0.00244213]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.01941287 0.7898735  0.13579902 0.04483307 0.01008151]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.04347397 0.4541844  0.37899542 0.09909456 0.02425163]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.02469009 0.6442723  0.2582315  0.05578891 0.0170172 ]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.01862334 0.70675707 0.21979791 0.0392173  0.01560437]
#
# prediction max =  1
#
# label =  Happy
#
#
#
#
# prediction =  [0.15307821 0.15502499 0.20993543 0.44770703 0.03425422]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.14444624 0.32408834 0.18252152 0.32619143 0.02275253]
#
# prediction max =  3
#
# label =  Sad
#
#
#
#
# prediction =  [0.11016037 0.04643165 0.5415319  0.27680632 0.02506968]
#
# prediction max =  2
#
# label =  Neutral
#
#
#
#
# prediction =  [0